# %% [markdown]
# # Load data and go to directory with python scripts

# %%
scripts_path = '/Users/jendawk/Dropbox (MIT)/C Diff Recurrence Paper/Analyses/scripts/'

# Path to save figures
path_to_save = '/'.join(scripts_path.split('/')[:-2]) + '/'

# Path to save supplementary and figure data folders
save_path = '/Users/jendawk/Dropbox (MIT)/C Diff Recurrence Paper/'
# %cd $scripts_path
# Out:
# /Users/jendawk/Dropbox (MIT)/C Diff Recurrence Paper/Analyses/scripts

# %%
from dataLoader import *
from helper import *
import scipy.stats as st
from collections import Counter
import sklearn
from matplotlib import cm
import scipy
import  itertools
from datetime import datetime

from seaborn import clustermap
from scipy.cluster.hierarchy import linkage
from sklearn.linear_model import LogisticRegression
import os
import time
import pickle as pkl
import re
from matplotlib_venn import venn3, venn2
from statsmodels.stats.multitest import multipletests
dl = dataLoader(pt_perc = {'metabs': .25, '16s': .05, 'scfa': 0, 'toxin':0}, meas_thresh = 
                {'metabs': 0, '16s': 10, 'scfa': 0, 'toxin':0}, 
                var_perc = {'metabs': 15, '16s': 5, 'scfa': 0, 'toxin':0})
# Out:
# /Users/jendawk/Dropbox (MIT)/C Diff Recurrence Paper/Analyses/scripts
# /Users/jendawk/miniconda3/envs/CodeBase/lib/python3.7/site-packages/pandas/core/generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %% [markdown]
# # Define functions for doing over representation analysis

# %%
import math
def combination(n,k):
    return math.factorial(n)/(math.factorial(k)*math.factorial(n-k))

def ora(x, X):
    N = len(X)
    n = len(x)
    print('n=' + str(n))
    num_hits = {}
    num_hits_expected = {}
    prob = {}
    for group in np.unique(x):
        k = np.sum(np.array(x)==group)
        K = np.sum(np.array(X)==group)
        if K < 4 or k < 3 or group == 'None' or group == 'Partially Characterized Molecules':
            print(group + ': K='+str(K) + ', k=' + str(k))
            continue
        num_hits[group] = k
        num_hits_expected[group] = (K/N)*n
        prob[group] = (combination(K,k)*combination(N-K, n-k))/combination(N,n)
    if len(prob)==0:
        return None

    gps, pvals = zip(*prob.items())
    reject, corrected, a1, a2 = multipletests(list(pvals), alpha=.05, method='fdr_bh')
    fdr = {gp:corr for gp, corr in zip(gps, corrected)}
    out_df = pd.DataFrame({'# Hits':num_hits, '# Expected Hits': num_hits_expected, 'p-value': prob, 'FDR': fdr})
    return out_df.sort_values('p-value', ascending = True)

# %% [markdown]
# # Enrichment analysis for metabolites

# %%
# Set path to where univariate analysis results of metabolites is stored
path = '/Users/jendawk/Dropbox (MIT)/C Diff Recurrence Paper/Analyses/univariate_analysis/metabs/'
for file in os.listdir(path):
    if '.csv' not in file:
        continue
    if 'ranksum' in file:
        continue
        
    df = pd.read_csv(path + file, index_col = 0)
    mets = df.index.values[df['BH corrected']<= 0.05]
    
    for pathway in ['SUPER_PATHWAY','SUB_PATHWAY']:
        K = dl.col_mat_mets[pathway].loc[df.index.values]
        k = dl.col_mat_mets[pathway].loc[mets]
        print(file)
        print(pathway)
        print(ora(k,K))
        print('')
# Out:
# ttest_metabs0_1_Non-recurrer.csv
# SUPER_PATHWAY
# n=228
# Energy: K=3, k=2
# Partially Characterized Molecules: K=21, k=7
#                         # Hits  # Expected Hits       p-value       FDR
# Nucleotide                  28             12.9  8.033942e-07  0.000006
# Amino Acid                  25             31.5  3.065450e-02  0.105318
# Xenobiotics                 60             65.4  4.513633e-02  0.105318
# Lipid                       89             88.8  6.462484e-02  0.113093
# Cofactors and Vitamins       6              9.0  8.185609e-02  0.114599
# Peptide                      6              8.1  1.206588e-01  0.140769
# Carbohydrate                 5              5.1  2.104611e-01  0.210461
#
# ttest_metabs0_1_Non-recurrer.csv
# SUB_PATHWAY
# n=228
# Aminosugar Metabolism: K=3, k=1
# Ceramides: K=2, k=2
# Chemical: K=14, k=1
# Dihydrosphingomyelins: K=1, k=1
# Drug - Antibiotic: K=1, k=1
# Drug - Other: K=1, k=1
# Fatty Acid Metabolism (Acyl Carnitine, Long Chain Saturated): K=3, k=1
# Fatty Acid Metabolism (Acyl Glutamine): K=3, k=1
# Glutamate Metabolism: K=6, k=1
# Glutathione Metabolism: K=2, k=2
# Glycine, Serine and Threonine Metabolism: K=4, k=1
# Hemoglobin and Porphyrin Metabolism: K=5, k=1
# Histidine Metabolism: K=7, k=2
# Inositol Metabolism: K=1, k=1
# Lactosylceramides (LCER): K=2, k=1
# Long Chain Monounsaturated Fatty Acid: K=1, k=1
# Long Chain Polyunsaturated Fatty Acid (n3 and n6): K=6, k=1
# Lysine Metabolism: K=6, k=1
# Nicotinate and Nicotinamide Metabolism: K=4, k=1
# Partially Characterized Molecules: K=21, k=7
# Phenylalanine Metabolism: K=7, k=1
# Phosphatidylcholine (PC): K=6, k=1
# Phosphatidylserine (PS): K=1, k=1
# Plasmalogen: K=2, k=2
# Polyamine Metabolism: K=6, k=2
# Primary Bile Acid Metabolism: K=10, k=1
# Progestin Steroids: K=5, k=1
# Pterin Metabolism: K=1, k=1
# Purine Metabolism, (Hypo)Xanthine/Inosine containing: K=2, k=1
# Purine Metabolism, Adenine containing: K=5, k=2
# Purine Metabolism, Guanine containing: K=5, k=2
# Pyrimidine Metabolism, Orotate containing: K=3, k=2
# Pyrimidine Metabolism, Thymine containing: K=2, k=1
# TCA Cycle: K=3, k=2
# Tocopherol Metabolism: K=7, k=2
# Tyrosine Metabolism: K=14, k=1
# Urea cycle; Arginine and Proline Metabolism: K=7, k=2
# Vitamin A Metabolism: K=4, k=1
#                                                   # Hits  # Expected Hits  \
# Sphingomyelins                                        14              4.2
# Dinucleotide                                          11              3.3
# Diacylglycerol                                        16              6.6
# Pyrimidine Metabolism, Cytidine containing             5              2.1
# Food Component/Plant                                  48             42.9
# Disaccharides and Oligosaccharides                     4              1.8
# Secondary Bile Acid Metabolism                         7             10.5
# Fatty Acid, Branched                                   3              1.2
# Fatty Acid Metabolism (Acyl Glycine)                   5              3.0
# Galactosyl Glycerolipids                               3              5.1
# Leucine, Isoleucine and Valine Metabolism              3              5.1
# Pyrimidine Metabolism, Uracil containing               4              2.4
# Sterol                                                 4              2.4
# Benzoate Metabolism                                    9              8.4
# Tryptophan Metabolism                                  6              4.8
# Fatty Acid, Dicarboxylate                              5              3.9
# Fatty Acid, Monohydroxy                                6              5.7
# Dipeptide                                              3              2.1
# Lysophospholipid                                       4              4.2
# Endocannabinoid                                        4              4.2
# Gamma-glutamyl Amino Acid                              3              3.6
# Methionine, Cysteine, SAM and Taurine Metabolism       3              2.4
# Monoacylglycerol                                       3              2.7
#
#                                                        p-value           FDR
# Sphingomyelins                                    3.590430e-08  8.257989e-07
# Dinucleotide                                      1.491072e-06  1.714732e-05
# Diacylglycerol                                    2.913275e-05  2.233511e-04
# Pyrimidine Metabolism, Cytidine containing        2.455074e-02  1.411668e-01
# Food Component/Plant                              4.666507e-02  2.146593e-01
# Disaccharides and Oligosaccharides                5.902825e-02  2.162012e-01
# Secondary Bile Acid Metabolism                    6.623753e-02  2.162012e-01
# Fatty Acid, Branched                              7.520043e-02  2.162012e-01
# Fatty Acid Metabolism (Acyl Glycine)              1.025554e-01  2.406669e-01
# Galactosyl Glycerolipids                          1.238428e-01  2.406669e-01
# Leucine, Isoleucine and Valine Metabolism         1.238428e-01  2.406669e-01
# Pyrimidine Metabolism, Uracil containing          1.360291e-01  2.406669e-01
# Sterol                                            1.360291e-01  2.406669e-01
# Benzoate Metabolism                               1.578383e-01  2.547720e-01
# Tryptophan Metabolism                             1.661557e-01  2.547720e-01
# Fatty Acid, Dicarboxylate                         1.814043e-01  2.607687e-01
# Fatty Acid, Monohydroxy                           1.940970e-01  2.626018e-01
# Dipeptide                                         2.276221e-01  2.641208e-01
# Lysophospholipid                                  2.310827e-01  2.641208e-01
# Endocannabinoid                                   2.310827e-01  2.641208e-01
# Gamma-glutamyl Amino Acid                         2.411537e-01  2.641208e-01
# Methionine, Cysteine, SAM and Taurine Metabolism  2.553720e-01  2.669798e-01
# Monoacylglycerol                                  2.684462e-01  2.684462e-01
#
# ttest_metabs1_2_Recurrer.csv
# SUPER_PATHWAY
# n=0
# None
#
# ttest_metabs1_2_Recurrer.csv
# SUB_PATHWAY
# n=0
# None
#
# ttest_metabs[1, 1.5, 2].csv
# SUPER_PATHWAY
# n=0
# None
#
# ttest_metabs[1, 1.5, 2].csv
# SUB_PATHWAY
# n=0
# None
#
# ttest_metabs1_2_Non-recurrer.csv
# SUPER_PATHWAY
# n=121
# Energy: K=3, k=1
# Partially Characterized Molecules: K=21, k=9
# Peptide: K=27, k=2
#                         # Hits  # Expected Hits   p-value       FDR
# Lipid                       43        47.126316  0.057624  0.117657
# Amino Acid                  13        16.717105  0.068237  0.117657
# Carbohydrate                 5         2.706579  0.078427  0.117657
# Xenobiotics                 33        34.707895  0.082288  0.117657
# Cofactors and Vitamins       7         4.776316  0.098047  0.117657
# Nucleotide                   8         6.846053  0.142108  0.142108
#
# ttest_metabs1_2_Non-recurrer.csv
# SUB_PATHWAY
# n=121
# Alanine and Aspartate Metabolism: K=3, k=1
# Aminosugar Metabolism: K=3, k=1
# Ascorbate and Aldarate Metabolism: K=2, k=1
# Dinucleotide: K=11, k=1
# Drug - Analgesics, Anesthetics: K=14, k=1
# Drug - Antibiotic: K=1, k=1
# Endocannabinoid: K=14, k=2
# Fatty Acid Metabolism (Acyl Carnitine, Monounsaturated): K=5, k=2
# Fatty Acid Metabolism (Acyl Glutamine): K=3, k=1
# Fructose, Mannose and Galactose Metabolism: K=2, k=1
# Gamma-glutamyl Amino Acid: K=12, k=2
# Glutamate Metabolism: K=6, k=1
# Glycine, Serine and Threonine Metabolism: K=4, k=1
# Hemoglobin and Porphyrin Metabolism: K=5, k=2
# Hexosylceramides (HCER): K=3, k=1
# Histidine Metabolism: K=7, k=1
# Inositol Metabolism: K=1, k=1
# Lactosylceramides (LCER): K=2, k=1
# Long Chain Polyunsaturated Fatty Acid (n3 and n6): K=6, k=2
# Lysoplasmalogen: K=2, k=1
# Methionine, Cysteine, SAM and Taurine Metabolism: K=8, k=1
# Pantothenate and CoA Metabolism: K=1, k=1
# Partially Characterized Molecules: K=21, k=9
# Polyamine Metabolism: K=6, k=1
# Progestin Steroids: K=5, k=2
# Purine Metabolism, Adenine containing: K=5, k=1
# Purine Metabolism, Guanine containing: K=5, k=1
# Pyrimidine Metabolism, Cytidine containing: K=7, k=1
# Pyrimidine Metabolism, Orotate containing: K=3, k=1
# Pyrimidine Metabolism, Thymine containing: K=2, k=1
# Pyrimidine Metabolism, Uracil containing: K=8, k=2
# Sphingosines: K=2, k=1
# Sterol: K=8, k=1
# TCA Cycle: K=3, k=1
# Tetrahydrobiopterin Metabolism: K=1, k=1
# Thiamine Metabolism: K=2, k=1
# Tocopherol Metabolism: K=7, k=1
# Tryptophan Metabolism: K=16, k=2
# Urea cycle; Arginine and Proline Metabolism: K=7, k=2
#                                                  # Hits  # Expected Hits  \
# Secondary Bile Acid Metabolism                       11         5.572368
# Primary Bile Acid Metabolism                          5         1.592105
# Fatty Acid Metabolism (Acyl Carnitine, Hydroxy)       3         0.636842
# Corticosteroids                                       3         0.796053
# Food Component/Plant                                 28        22.767105
# Disaccharides and Oligosaccharides                    3         0.955263
# Benzoate Metabolism                                   3         4.457895
# Androgenic Steroids                                   3         2.547368
# Leucine, Isoleucine and Valine Metabolism             3         2.706579
# Fatty Acid, Monohydroxy                               3         3.025000
#
#                                                   p-value       FDR
# Secondary Bile Acid Metabolism                   0.009694  0.044477
# Primary Bile Acid Metabolism                     0.010408  0.044477
# Fatty Acid Metabolism (Acyl Carnitine, Hydroxy)  0.013343  0.044477
# Corticosteroids                                  0.028151  0.070377
# Food Component/Plant                             0.040901  0.079171
# Disaccharides and Oligosaccharides               0.047502  0.079171
# Benzoate Metabolism                              0.173662  0.246994
# Androgenic Steroids                              0.239816  0.246994
# Leucine, Isoleucine and Valine Metabolism        0.245019  0.246994
# Fatty Acid, Monohydroxy                          0.246994  0.246994
#
# ttest_metabs2.csv
# SUPER_PATHWAY
# n=23
# Amino Acid: K=105, k=1
# Carbohydrate: K=17, k=1
# Cofactors and Vitamins: K=30, k=1
#              # Hits  # Expected Hits   p-value       FDR
# Lipid            15         8.957895  0.006256  0.012513
# Xenobiotics       5         6.597368  0.149470  0.149470
#
# ttest_metabs2.csv
# SUB_PATHWAY
# n=23
# Androgenic Steroids: K=16, k=2
# Corticosteroids: K=5, k=1
# Disaccharides and Oligosaccharides: K=6, k=1
# Drug - Analgesics, Anesthetics: K=14, k=1
# Endocannabinoid: K=14, k=2
# Estrogenic Steroids: K=2, k=1
# Hemoglobin and Porphyrin Metabolism: K=5, k=1
# Lysophospholipid: K=14, k=1
# Phosphatidylcholine (PC): K=6, k=1
# Progestin Steroids: K=5, k=1
# Secondary Bile Acid Metabolism: K=35, k=2
# Urea cycle; Arginine and Proline Metabolism: K=7, k=1
#                       # Hits  # Expected Hits   p-value       FDR
# Sphingomyelins             4         0.423684  0.000498  0.000995
# Food Component/Plant       4         4.327632  0.214439  0.214439
#
# ttest_metabs0_1_Recurrer.csv
# SUPER_PATHWAY
# n=43
# Cofactors and Vitamins: K=30, k=1
#              # Hits  # Expected Hits   p-value       FDR
# Xenobiotics       5        12.334211  0.004186  0.020930
# Lipid            24        16.747368  0.008928  0.022321
# Nucleotide        6         2.432895  0.020999  0.034998
# Peptide           3         1.527632  0.131836  0.136178
# Amino Acid        4         5.940789  0.136178  0.136178
#
# ttest_metabs0_1_Recurrer.csv
# SUB_PATHWAY
# n=43
# Acetylated Peptides: K=7, k=1
# Benzoate Metabolism: K=28, k=1
# Dinucleotide: K=11, k=2
# Dipeptide: K=7, k=1
# Fatty Acid Metabolism (Acyl Carnitine, Hydroxy): K=4, k=2
# Fatty Acid Metabolism (Acyl Carnitine, Monounsaturated): K=5, k=1
# Fatty Acid, Dicarboxylate: K=13, k=2
# Fatty Acid, Monohydroxy: K=19, k=2
# Gamma-glutamyl Amino Acid: K=12, k=1
# Hemoglobin and Porphyrin Metabolism: K=5, k=1
# Histidine Metabolism: K=7, k=1
# Long Chain Monounsaturated Fatty Acid: K=1, k=1
# Long Chain Polyunsaturated Fatty Acid (n3 and n6): K=6, k=1
# Lysophospholipid: K=14, k=2
# Monoacylglycerol: K=9, k=1
# Plasmalogen: K=2, k=2
# Purine Metabolism, (Hypo)Xanthine/Inosine containing: K=2, k=1
# Pyrimidine Metabolism, Cytidine containing: K=7, k=2
# Pyrimidine Metabolism, Uracil containing: K=8, k=1
# Sterol: K=8, k=1
#                        # Hits  # Expected Hits   p-value       FDR
# Sphingomyelins              5         0.792105  0.000579  0.002317
# Diacylglycerol              4         1.244737  0.024949  0.046552
# Food Component/Plant        4         8.090789  0.043012  0.046552
# Tryptophan Metabolism       3         0.905263  0.046552  0.046552
#
# ttest_metabs0.csv
# SUPER_PATHWAY
# n=0
# None
#
# ttest_metabs0.csv
# SUB_PATHWAY
# n=0
# None
#
# ttest_metabs1.csv
# SUPER_PATHWAY
# n=0
# None
#
# ttest_metabs1.csv
# SUB_PATHWAY
# n=0
# None

# %% [markdown]
# # Enrichment analysis for ASVs

# %%
path = '/Users/jendawk/Dropbox (MIT)/C Diff Recurrence Paper/Analyses/univariate_analysis/16s/'
path_taxa = '/Users/jendawk/Dropbox (MIT)/C Diff Recurrence Paper/Analyses/scripts/inputs/'
taxa_rdp = pd.read_csv(path_taxa + 'dada2-taxonomy-rdp.csv', index_col = 0)
taxa_silva = pd.read_csv(path_taxa + 'dada2-taxonomy-silva.csv', index_col = 0)
for file in os.listdir(path):
    if '.csv' not in file:
        continue
        
    df = pd.read_csv(path + file, index_col = 0)
    for fname, taxa in zip(['rdp','silva'],[taxa_rdp, taxa_silva]):
        FAM = taxa[df.index.values].loc['Family'].dropna()
        GEN = taxa[df.index.values].loc['Genus'].dropna()

        mets = df.index.values[df['padj']<= 0.05]
        fam = taxa[mets].loc['Family'].dropna()
        gen = taxa[mets].loc['Genus'].dropna()
        print(file)
        print(fname)
        print('Family')
        print(ora(fam, FAM))
        print('Genus')
        print(ora(gen,GEN))
        print('')
# Out:
# deseq2_16sNon-recurrer1_2.csv
# rdp
# Family
# n=12
# Bacteroidaceae: K=14, k=1
# Erysipelotrichaceae: K=12, k=1
# Prevotellaceae: K=10, k=1
# Ruminococcaceae: K=18, k=1
# Veillonellaceae: K=21, k=1
# Verrucomicrobiaceae: K=2, k=1
#                  # Hits  # Expected Hits   p-value       FDR
# Lachnospiraceae       6          3.06383  0.041147  0.041147
# Genus
# n=12
# Akkermansia: K=2, k=1
# Bacteroides: K=13, k=1
# Clostridium_XVIII: K=3, k=1
# Faecalibacterium: K=5, k=1
# Fusicatenibacter: K=1, k=1
# Prevotella: K=10, k=1
# Roseburia: K=4, k=1
# Ruminococcus2: K=3, k=1
# Veillonella: K=9, k=1
#                   # Hits  # Expected Hits   p-value       FDR
# Clostridium_XlVa       3         1.023697  0.058486  0.058486
#
# deseq2_16sNon-recurrer1_2.csv
# silva
# Family
# n=12
# Akkermansiaceae: K=2, k=1
# Bacteroidaceae: K=13, k=1
# Erysipelatoclostridiaceae: K=5, k=1
# Prevotellaceae: K=10, k=1
# Ruminococcaceae: K=13, k=1
# Veillonellaceae: K=19, k=1
#                  # Hits  # Expected Hits   p-value       FDR
# Lachnospiraceae       6         3.128205  0.044841  0.044841
# Genus
# n=11
# Akkermansia: K=2, k=1
# Bacteroides: K=13, k=1
# Erysipelatoclostridium: K=3, k=1
# Faecalibacterium: K=4, k=1
# Fusicatenibacter: K=1, k=1
# Lachnospiraceae NK4A136 group: K=4, k=1
# Lachnospiraceae UCG-009: K=1, k=1
# Prevotella: K=7, k=1
# Roseburia: K=2, k=1
# Veillonella: K=9, k=1
# [Ruminococcus] torques group: K=4, k=1
# None
#
# deseq2_16s0.csv
# rdp
# Family
# n=10
# Bacteroidaceae: K=14, k=1
# Methanobacteriaceae: K=1, k=1
# Porphyromonadaceae: K=4, k=1
# Ruminococcaceae: K=18, k=2
# Veillonellaceae: K=21, k=1
#                  # Hits  # Expected Hits   p-value       FDR
# Lachnospiraceae       4         2.553191  0.153024  0.153024
# Genus
# n=8
# Anaerostipes: K=2, k=1
# Bacteroides: K=13, k=1
# Blautia: K=9, k=1
# Eisenbergiella: K=2, k=1
# Faecalibacterium: K=5, k=1
# Methanobrevibacter: K=1, k=1
# Odoribacter: K=1, k=1
# Veillonella: K=9, k=1
# None
#
# deseq2_16s0.csv
# silva
# Family
# n=10
# Bacteroidaceae: K=13, k=1
# Marinifilaceae: K=1, k=1
# Methanobacteriaceae: K=1, k=1
# Monoglobaceae: K=1, k=1
# Ruminococcaceae: K=13, k=1
# Veillonellaceae: K=19, k=1
#                  # Hits  # Expected Hits   p-value       FDR
# Lachnospiraceae       4         2.606838  0.159481  0.159481
# Genus
# n=10
# Anaerostipes: K=2, k=1
# Bacteroides: K=13, k=1
# Blautia: K=9, k=1
# Eisenbergiella: K=2, k=1
# Faecalibacterium: K=4, k=1
# Methanobrevibacter: K=1, k=1
# Monoglobus: K=1, k=1
# Odoribacter: K=1, k=1
# Veillonella: K=9, k=1
# [Eubacterium] hallii group: K=3, k=1
# None
#
# deseq2_16sRecurrer1_2.csv
# rdp
# Family
# n=8
# Bacteroidaceae: K=14, k=1
# Clostridiaceae_1: K=12, k=2
# Desulfovibrionaceae: K=1, k=1
# Enterococcaceae: K=4, k=1
# Lachnospiraceae: K=60, k=1
# Veillonellaceae: K=21, k=1
# Verrucomicrobiaceae: K=2, k=1
# None
# Genus
# n=8
# Akkermansia: K=2, k=1
# Bacteroides: K=13, k=1
# Bilophila: K=1, k=1
# Clostridium_sensu_stricto: K=12, k=2
# Enterococcus: K=3, k=1
# Hungatella: K=1, k=1
# Propionispira: K=1, k=1
# None
#
# deseq2_16sRecurrer1_2.csv
# silva
# Family
# n=8
# Akkermansiaceae: K=2, k=1
# Bacteroidaceae: K=13, k=1
# Clostridiaceae: K=12, k=2
# Desulfovibrionaceae: K=1, k=1
# Enterococcaceae: K=3, k=1
# Lachnospiraceae: K=61, k=1
# Selenomonadaceae: K=2, k=1
# None
# Genus
# n=7
# Akkermansia: K=2, k=1
# Bacteroides: K=13, k=1
# Bilophila: K=1, k=1
# Clostridium sensu stricto 1: K=9, k=1
# Clostridium sensu stricto 2: K=1, k=1
# Enterococcus: K=3, k=1
# Hungatella: K=2, k=1
# None
#
# deseq2_16s1.csv
# rdp
# Family
# n=8
# Acidaminococcaceae: K=2, k=1
# Bacteroidaceae: K=14, k=1
# Bifidobacteriaceae: K=5, k=1
# Enterobacteriaceae: K=14, k=1
# Lachnospiraceae: K=60, k=1
# Ruminococcaceae: K=18, k=1
# Streptococcaceae: K=7, k=1
# Veillonellaceae: K=21, k=1
# None
# Genus
# n=8
# Bacteroides: K=13, k=1
# Bifidobacterium: K=4, k=1
# Blautia: K=9, k=1
# Faecalibacterium: K=5, k=1
# Phascolarctobacterium: K=1, k=1
# Streptococcus: K=6, k=1
# Veillonella: K=9, k=1
# Yersinia: K=1, k=1
# None
#
# deseq2_16s1.csv
# silva
# Family
# n=7
# Acidaminococcaceae: K=2, k=1
# Bacteroidaceae: K=13, k=1
# Bifidobacteriaceae: K=5, k=1
# Lachnospiraceae: K=61, k=1
# Ruminococcaceae: K=13, k=1
# Streptococcaceae: K=7, k=1
# Veillonellaceae: K=19, k=1
# None
# Genus
# n=7
# Bacteroides: K=13, k=1
# Bifidobacterium: K=4, k=1
# Blautia: K=9, k=1
# Faecalibacterium: K=4, k=1
# Phascolarctobacterium: K=1, k=1
# Streptococcus: K=6, k=1
# Veillonella: K=9, k=1
# None
#
# deseq2_16s2.csv
# rdp
# Family
# n=29
# Acidaminococcaceae: K=2, k=1
# Bifidobacteriaceae: K=5, k=1
# Desulfovibrionaceae: K=1, k=1
# Enterobacteriaceae: K=14, k=2
# Erysipelotrichaceae: K=12, k=1
# Veillonellaceae: K=21, k=1
# Verrucomicrobiaceae: K=2, k=1
#                  # Hits  # Expected Hits   p-value       FDR
# Ruminococcaceae       6         2.221277  0.010918  0.032754
# Lachnospiraceae      11         7.404255  0.047690  0.059590
# Bacteroidaceae        4         1.727660  0.059590  0.059590
# Genus
# n=28
# Akkermansia: K=2, k=1
# Anaerostipes: K=2, k=1
# Anaerotruncus: K=1, k=1
# Bifidobacterium: K=4, k=1
# Bilophila: K=1, k=1
# Citrobacter: K=1, k=1
# Clostridium_IV: K=3, k=2
# Clostridium_XlVa: K=18, k=2
# Coprobacillus: K=1, k=1
# Faecalibacterium: K=5, k=1
# Fusicatenibacter: K=1, k=1
# Oscillibacter: K=1, k=1
# Phascolarctobacterium: K=1, k=1
# Proteus: K=2, k=1
# Roseburia: K=4, k=2
# Subdoligranulum: K=1, k=1
# Veillonella: K=9, k=1
#              # Hits  # Expected Hits   p-value       FDR
# Blautia           4         1.194313  0.017247  0.034493
# Bacteroides       4         1.725118  0.058770  0.058770
#
# deseq2_16s2.csv
# silva
# Family
# n=29
# Acidaminococcaceae: K=2, k=1
# Akkermansiaceae: K=2, k=1
# Bifidobacteriaceae: K=5, k=1
# Desulfovibrionaceae: K=1, k=1
# Enterobacteriaceae: K=9, k=1
# Erysipelatoclostridiaceae: K=5, k=1
# Morganellaceae: K=3, k=1
# Oscillospiraceae: K=2, k=1
# Veillonellaceae: K=19, k=1
# [Eubacterium] coprostanoligenes group: K=1, k=1
#                  # Hits  # Expected Hits   p-value       FDR
# Bacteroidaceae        4         1.611111  0.048557  0.053386
# Ruminococcaceae       4         1.611111  0.048557  0.053386
# Lachnospiraceae      11         7.559829  0.053386  0.053386
# Genus
# n=27
# Agathobacter: K=2, k=1
# Akkermansia: K=2, k=1
# Anaerostipes: K=2, k=1
# Bifidobacterium: K=4, k=1
# Bilophila: K=1, k=1
# Coprobacillus: K=1, k=1
# Faecalibacterium: K=4, k=1
# Fusicatenibacter: K=1, k=1
# Incertae Sedis: K=4, k=2
# Lachnoclostridium: K=7, k=1
# Oscillibacter: K=1, k=1
# Phascolarctobacterium: K=1, k=1
# Pluralibacter: K=1, k=1
# Proteus: K=2, k=1
# Roseburia: K=2, k=1
# UBA1819: K=1, k=1
# Veillonella: K=9, k=1
# [Ruminococcus] gnavus group: K=1, k=1
#              # Hits  # Expected Hits   p-value       FDR
# Blautia           4         1.070485  0.011848  0.023696
# Bacteroides       4         1.546256  0.042901  0.042901
#
# deseq2_16sNon-recurrer0_1.csv
# rdp
# Family
# n=31
# Erysipelotrichaceae: K=12, k=2
# Fusobacteriaceae: K=9, k=1
# Peptostreptococcaceae: K=6, k=1
# Prevotellaceae: K=10, k=1
# Rikenellaceae: K=4, k=1
# Ruminococcaceae: K=18, k=2
# Veillonellaceae: K=21, k=2
# Verrucomicrobiaceae: K=2, k=1
#                     # Hits  # Expected Hits   p-value       FDR
# Lactobacillaceae         5         1.714894  0.014407  0.057626
# Bacteroidaceae           4         1.846809  0.071448  0.095264
# Enterobacteriaceae       4         1.846809  0.071448  0.095264
# Lachnospiraceae          7         7.914894  0.166053  0.166053
# Genus
# n=28
# Akkermansia: K=2, k=1
# Alistipes: K=4, k=1
# Anaerostipes: K=2, k=1
# Clostridium_XI: K=1, k=1
# Clostridium_XVIII: K=3, k=2
# Clostridium_XlVa: K=18, k=1
# Coprococcus: K=1, k=1
# Fusicatenibacter: K=1, k=1
# Fusobacterium: K=9, k=1
# Megasphaera: K=1, k=1
# Morganella: K=1, k=1
# Oscillibacter: K=1, k=1
# Pediococcus: K=2, k=1
# Prevotella: K=10, k=1
# Proteus: K=2, k=1
# Roseburia: K=4, k=1
# Ruminococcus2: K=3, k=1
# Veillonella: K=9, k=1
# Yersinia: K=1, k=1
#                # Hits  # Expected Hits  p-value      FDR
# Lactobacillus       4         1.459716  0.03505  0.05877
# Bacteroides         4         1.725118  0.05877  0.05877
#
# deseq2_16sNon-recurrer0_1.csv
# silva
# Family
# n=30
# Akkermansiaceae: K=2, k=1
# Enterobacteriaceae: K=9, k=1
# Erysipelatoclostridiaceae: K=5, k=2
# Fusobacteriaceae: K=9, k=1
# Monoglobaceae: K=1, k=1
# Morganellaceae: K=3, k=2
# Oscillospiraceae: K=2, k=1
# Peptostreptococcaceae: K=6, k=1
# Prevotellaceae: K=10, k=1
# Rikenellaceae: K=4, k=1
# Veillonellaceae: K=19, k=2
#                   # Hits  # Expected Hits   p-value       FDR
# Lactobacillaceae       5         1.666667  0.012791  0.038372
# Bacteroidaceae         4         1.666667  0.053567  0.080351
# Lachnospiraceae        7         7.820513  0.169234  0.169234
# Genus
# n=28
# Akkermansia: K=2, k=1
# Alistipes: K=4, k=1
# Anaerostipes: K=2, k=1
# Clostridioides: K=1, k=1
# Coprococcus: K=1, k=1
# Erysipelatoclostridium: K=3, k=1
# Erysipelotrichaceae UCG-003: K=1, k=1
# Fusicatenibacter: K=1, k=1
# Fusobacterium: K=9, k=1
# Megasphaera: K=1, k=1
# Monoglobus: K=1, k=1
# Morganella: K=1, k=1
# Oscillibacter: K=1, k=1
# Pediococcus: K=2, k=1
# Prevotella: K=7, k=1
# Proteus: K=2, k=1
# Roseburia: K=2, k=1
# Veillonella: K=9, k=1
# [Eubacterium] hallii group: K=3, k=1
# [Ruminococcus] torques group: K=4, k=1
#                # Hits  # Expected Hits   p-value       FDR
# Lactobacillus       4         1.356828  0.027937  0.047799
# Bacteroides         4         1.603524  0.047799  0.047799
#
# deseq2_16sRecurrer0_1.csv
# rdp
# Family
# n=21
# Bacteroidaceae: K=14, k=2
# Desulfovibrionaceae: K=1, k=1
# Enterobacteriaceae: K=14, k=1
# Enterococcaceae: K=4, k=1
# Porphyromonadaceae: K=4, k=2
# Prevotellaceae: K=10, k=1
# Rikenellaceae: K=4, k=1
# Streptococcaceae: K=7, k=1
# Verrucomicrobiaceae: K=2, k=1
#                   # Hits  # Expected Hits   p-value       FDR
# Lactobacillaceae       4         1.161702  0.017146  0.051437
# Lachnospiraceae        3         5.361702  0.106026  0.159039
# Veillonellaceae        3         1.876596  0.182577  0.182577
# Genus
# n=20
# Akkermansia: K=2, k=1
# Alistipes: K=4, k=1
# Bacteroides: K=13, k=2
# Bilophila: K=1, k=1
# Dialister: K=3, k=1
# Dorea: K=1, k=1
# Enterobacter: K=1, k=1
# Enterococcus: K=3, k=1
# Parabacteroides: K=3, k=2
# Pediococcus: K=2, k=1
# Prevotella: K=10, k=1
# Propionispira: K=1, k=1
# Ruminococcus2: K=3, k=1
# Streptococcus: K=6, k=1
# Veillonella: K=9, k=1
#                # Hits  # Expected Hits   p-value       FDR
# Lactobacillus       3         1.042654  0.060858  0.060858
#
# deseq2_16sRecurrer0_1.csv
# silva
# Family
# n=21
# Akkermansiaceae: K=2, k=1
# Bacteroidaceae: K=13, k=2
# Desulfovibrionaceae: K=1, k=1
# Enterobacteriaceae: K=9, k=1
# Enterococcaceae: K=3, k=1
# Prevotellaceae: K=10, k=1
# Rikenellaceae: K=4, k=1
# Selenomonadaceae: K=2, k=1
# Streptococcaceae: K=7, k=1
# Tannerellaceae: K=3, k=2
# Veillonellaceae: K=19, k=2
#                   # Hits  # Expected Hits   p-value       FDR
# Lactobacillaceae       4         1.166667  0.017386  0.034773
# Lachnospiraceae        3         5.474359  0.098493  0.098493
# Genus
# n=20
# Akkermansia: K=2, k=1
# Alistipes: K=4, k=1
# Bacteroides: K=13, k=2
# Bilophila: K=1, k=1
# Dialister: K=2, k=1
# Dorea: K=1, k=1
# Enterococcus: K=3, k=1
# Klebsiella: K=2, k=1
# Parabacteroides: K=3, k=2
# Pediococcus: K=2, k=1
# Prevotella: K=7, k=1
# Sellimonas: K=1, k=1
# Streptococcus: K=6, k=1
# Veillonella: K=9, k=1
# [Ruminococcus] torques group: K=4, k=1
#                # Hits  # Expected Hits   p-value       FDR
# Lactobacillus       3         0.969163  0.051456  0.051456
